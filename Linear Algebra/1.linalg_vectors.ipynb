# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ---
# # VIDEO: Algebraic and geometric interpretations
# ---

# %%
# 2-dimensional vector
v2 = [ 3, -2 ]
# 3-dimensional vector
v3 = [ 4, -3, 2 ]
# row to column (or vice-versa):
v3t = np.transpose(v3)
# plot them x, y ([0 to 3],([0 to -2])
# it starts from 0 because it is how we describe vector in general
plt.plot([0,v2[0]],[0,v2[1]])

# %%
#Make sure the x, y axis are in the same ratio.
plt.axis('equal')
# k --> black, -- --> Dashed line
plt.plot([-4, 4],[0, 0],'y--')
plt.plot([0, 0],[-4, 4],'k--')
#격자선
plt.grid()
# Sets the limit of the axis
plt.axis((-4, 4, -4, 4))
plt.show()

# %%
# plot the 3D vector
# figure --> create a new figure
# figsize --> width, height in inches. If not provided, defaults to 
# rcParams["figure.figsize"] = [6.4, 4.8] = [6.4, 4.8].
# figaspect --> Calculate the width and height for a figure with a specified aspect ratio
fig = plt.figure(figsize=plt.figaspect(1))
# gca --> Get the current Axes instance on the current figure matching the given keyword args, or create one.
# projection= 3d --> To get the current 3d axes on the current figure:
# If the current axes doesn't exist, or isn't a polar one, 
#the appropriate axes will be created and then returned.
ax = fig.gca(projection='3d')
ax.plot([0, v3[0]],[0, v3[1]],[0, v3[2]],linewidth=3)

# make the plot look nicer
ax.plot([0, 0],[0, 0],[-4, 4],'k--')
ax.plot([0, 0],[-4, 4],[0, 0],'k--')
ax.plot([-4, 4],[0, 0],[0, 0],'k--')
plt.show()

# %% [markdown]
# ---
# # VIDEO: Vector addition/subtraction
# ---

# %%
# two vectors in R2
v1 = np.array([ 3, -1 ])
v2 = np.array([ 2,  4 ])

v3 = v1 + v2
v3
# Out:
# array([5, 3])

# %%
# plot them
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v1')
# Keep in mind that it starts from the head of the v1
plt.plot([0, v2[0]]+v1[0],[0, v2[1]]+v1[1],'r',label='v2')
plt.plot([0, v3[0]],[0, v3[1]],'k',label='v1+v2')

# show the info of the graph on top right corner
plt.legend()
plt.axis('square')
plt.axis((-6, 6, -6, 6 ))
plt.grid()
plt.show()

# %% [markdown]
# ---
# # VIDEO: Vector-scalar multiplication
# ---

# %%
# vector and scalar
v1 = np.array([ 3, -1 ])
l  = -.3
v1m = v1*l # scalar-modulated

# plot them
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v_1')
plt.plot([0, v1m[0]],[0, v1m[1]],'r:',label='\lambda v_1')
plt.legend();

plt.axis('square')
plt.axis((-3,3,-3,3))
plt.grid()
plt.show()

# %% [markdown]
# ---
# # VIDEO: Vector-vector multiplication: the dot product
# ---

# %%
## many ways to compute the dot product

v1 = np.array([ 1, 2, 3, 4, 5, 6 ])
v2 = np.array([ 0, -4, -3, 6, 5, 3 ])

# method 1
dp = sum( np.multiply(v1,v2) )

# method 2
dp = np.dot( v1,v2 )

# method 3
dp = np.matmul( v1,v2 )

# method 4
dp = 0  # initialize

# loop over elements
for i in range(0,len(v1)):
    
    # multiply corresponding element and sum
    dp = dp + v1[i]*v2[i]
    
print(dp)
# Out:
# 50

# %% [markdown]
# # VIDEO: Dot product properties: associative and distributive

# %%
## Distributive property

# create random vectors
n = 10
a = np.random.randn(n)
b = np.random.randn(n)
c = np.random.randn(n)

# the two results
res1 = np.dot( a , (b+c) )
res2 = np.dot(a,b) + np.dot(a,c)

# compare them
print([ res1,res2 ])
# Out:
# [1.644521060769953, 1.6445210607699532]

# %%
## Associative property

# create random vectors
n = 10
a = np.random.randn(n)
b = np.random.randn(n)
c = np.random.randn(n)

# the two results
res1 = np.dot( a , np.dot(b,c) )
res2 = np.dot( np.dot(a,b) , c )

# compare them
print(res1)
print(res2)

### special cases where associative property works!
# 1) one vector is the zeros vector
# 2) a==b==c
# Out:
# [ 1.55046824 -1.17669239 -1.60074118 -1.04032665 -1.50722642 -0.07286815
#   0.77474077  1.40844721  0.55087981 -0.27067356]
# [  2.01373356  -1.27893      5.34726301  -5.08528357 -11.05695711
#    0.55448744  -2.88478085   3.11581042  -0.46881017  -6.79023636]

# %%
#Challenge1. Create 2 matrices with 4*6 of random numbers, use for loop to compute dot products 
# it is not original dot product on matrix. Just column wise dot product calculation
np.random.seed(0)
m = 4
n = 6
a = np.random.randint(0, 10, (m,n))
b = np.random.randint(0, 10, (m,n))
dp = np.zeros(6)

for i in range(n):
        dp[i] = np.dot(a[:,i], b[:,i])
print(dp)
# Out:
# [ 50.  75.  51.  46. 135. 144.]

# %%
#solution
print('This is the first Matrix A:')
print(a)
print('This is the second Matrix B:')
print(b)
# loop to compute the dot product between the corresponding columns:
for i in range(a.shape[1]):
    dp = np.dot(a[:,i],b[:,i])
    print(f'The dot product between column {i+1} is: {dp}')
# Out:
# This is the first Matrix A:
# [[5 0 3 3 7 9]
#  [3 5 2 4 7 6]
#  [8 8 1 6 7 7]
#  [8 1 5 9 8 9]]
# This is the second Matrix B:
# [[4 3 0 3 5 0]
#  [2 3 8 1 3 3]
#  [3 7 0 1 9 9]
#  [0 4 7 3 2 7]]
# The dot product between column 1 is: 50
# The dot product between column 2 is: 75
# The dot product between column 3 is: 51
# The dot product between column 4 is: 46
# The dot product between column 5 is: 135
# The dot product between column 6 is: 144

# %% [markdown]
# ---
# # VIDEO: Vector length
# ---

# %%
# a vector
v1 = np.array([ 1, 2, 3, 4, 5, 6, ])

# methods 1-4, just like with the regular dot product, e.g.:
vl = np.sqrt( sum( np.multiply(v1,v1)) )

vl
# Out:
# 9.539392014169456

# %%
# method 5: take the norm
vl = np.linalg.norm(v1)

print(vl)
# Out:
# 9.539392014169456

# %% [markdown]
# ---
# # VIDEO: The dot product from a geometric perspective
# ---

# %%
# two vectors
v1 = np.array([ 2,  4, -3 ])
v2 = np.array([ 0, -3, -3 ])

# compute the angle (radians) between two vectors
ang = np.arccos( np.dot(v1,v2) / (np.linalg.norm(v1)*np.linalg.norm(v2)) )


# draw them
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot([0, v1[0]],[0, v1[1]],[0, v1[2]],'b')
ax.plot([0, v2[0]],[0, v2[1]],[0, v2[2]],'r')

plt.axis((-6, 6, -6, 6))
#dynamically give the value
plt.title('Angle between vectors: %s rad.' %ang)
plt.show()

# %%
## equivalence of algebraic and geometric dot product formulas

# two vectors
v1 = np.array([ 2,  4, -3 ])
v2 = np.array([ 0, -3, -3 ])


# algebraic
dp_a = np.dot( v1,v2 )

# geometric
dp_g = np.linalg.norm(v1)*np.linalg.norm(v2)*np.cos(ang)

# print dot product to command
print(dp_a)
print(dp_g)
# Out:
# -3
# -3.0000000000000013

# %%
#Challange2 test weather the dot product sign is invaraint(not affected by) to scalar multiplication
# generate two vectors (R3)
# generate two scalars
# compute the dot product between vectors
# compute the dot product between the scaled vectors.
np.random.seed(0)
vec1 = np.random.randint(0,10,3)
vec2 = np.random.randint(0,10,3)
print(vec1)
print(vec2)
sca1 = 4
sca2 = -2
dp = np.dot(vec1, vec2)
dp_scaled = np.dot(vec1*sca1, vec2*sca2)
print(dp)
print(dp_scaled)
print(f'dp_scaled is {dp}(dp) times {sca1} x {sca2}')
# Out:
# [5 0 3]
# [3 7 9]
# 42
# -336
# dp_scaled is 42(dp) times 4 x -2

# %%
#Challenge3 Is the dot product commutative?
# generate two 100 element random row vectors, compute dot product a with b b with a 
# generate two 2 elemenet integer row vectors, repeat
np.random.seed(0)
a = np.random.randint(0, 10, 100)
b = np.random.randint(0, 10, 100)
print(a)
print(b)
a_b = np.dot(a, b)
b_a = np.dot(b, a)
print(a_b)
print(b_a)
print('answer: yes they are commutative')
# Out:
# [5 0 3 3 7 9 3 5 2 4 7 6 8 8 1 6 7 7 8 1 5 9 8 9 4 3 0 3 5 0 2 3 8 1 3 3 3
#  7 0 1 9 9 0 4 7 3 2 7 2 0 0 4 5 5 6 8 4 1 4 9 8 1 1 7 9 9 3 6 7 2 0 3 5 9
#  4 4 6 4 4 3 4 4 8 4 3 7 5 5 0 1 5 9 3 0 5 0 1 2 4 2]
# [0 3 2 0 7 5 9 0 2 7 2 9 2 3 3 2 3 4 1 2 9 1 4 6 8 2 3 0 0 6 0 6 3 3 8 8 8
#  2 3 2 0 8 8 3 8 2 8 4 3 0 4 3 6 9 8 0 8 5 9 0 9 6 5 3 1 8 0 4 9 6 5 7 8 8
#  9 2 8 6 6 9 1 6 8 8 3 2 3 6 3 6 5 7 0 8 4 6 5 8 2 3]
# 1981
# 1981
# answer: yes they are commutative

# %%
#dot product of matrix
sample1 = np.arange(1,9).reshape(2,4)
print(sample1)
sample2 = np.transpose(sample1)
print(sample2)

dp = np.dot(sample1, sample2)
dp
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]
# [[1 5]
#  [2 6]
#  [3 7]
#  [4 8]]
# array([[ 30,  70],
#        [ 70, 174]])

# %% [markdown]
# ---
# # VIDEO: Vector Hadamard multiplication
# ---

# %%
# create vectors
w1 = [ 1, 3, 5 ]
w2 = [ 3, 4, 2 ]

w3 = np.multiply(w1,w2)
print(w3)
# Out:
# [ 3 12 10]

# %% [markdown]
# ---
# # VIDEO: Vector outer product
# ---

# %%
v1 = np.array([  1, 2, 3 ])
v2 = np.array([ -1, 0, 1 ])

# outer product
op1 = np.outer(v1,v2)

# terrible programming, but helps conceptually:
op = np.zeros((len(v1),len(v1)))
for i in range(0,len(v1)):
    for j in range(0,len(v2)):
        op[i,j] = v1[i] * v2[j]

print(op)
print(op1)
# Out:
# [[-1.  0.  1.]
#  [-2.  0.  2.]
#  [-3.  0.  3.]]
# [[-1  0  1]
#  [-2  0  2]
#  [-3  0  3]]
# [ 2 -4  2]

# %% [markdown]
# ---
# # VIDEO: Vector cross product
# ---

# %%
# create vectors
v1  = [ -3,  2, 5 ]
v2  = [  4, -3, 0 ]

# Python's cross-product function
v3a = np.cross( v1,v2 )
print(v3a)

# "manual" method
v3b = [ [v1[1]*v2[2] - v1[2]*v2[1]],
        [v1[2]*v2[0] - v1[0]*v2[2]],
        [v1[0]*v2[1] - v1[1]*v2[0]] ]

fig = plt.figure()
ax = fig.gca(projection='3d')

# draw plane defined by span of v1 and v2
xx, yy = np.meshgrid(np.linspace(-10,10,10),np.linspace(-10,10,10))
z1 = (-v3a[0]*xx - v3a[1]*yy)/v3a[2]
# --> think of it as k = ax + by + cz
# z = (k - ax - by)/ c
# if we put x, y, z as a 0, thinking it's origin , k =0;
# input the value in to the equation above. we get the value 
# https://www.udemy.com/course/linear-algebra-theory-and-implementation/learn/lecture/14169807#questions/8662630
# print(z1)
ax.plot_surface(xx,yy,z1)

## plot the two vectors
# ax.plot([0, v1[0]],[0, v1[1]],[0, v1[2]],'g')
# ax.plot([0, v2[0]],[0, v2[1]],[0, v2[2]],'g')
ax.plot([0, v3a[0]],[0, v3a[1]],[0, v3a[2]],'r')

##elev = Elevation viewing angle, defaults to 30., azim = Azimuthal viewing angle, defaults to -60.
ax.view_init(azim=150,elev=45)
plt.show()
# Out:
# [15 20  1]

# %% [markdown]
# ---
# # VIDEO: Hermitian transpose (a.k.a. conjugate transpose)
# ---

# %%
# create a complex number
z = np.complex(3,4)
print(z)

# magnitude
print( np.linalg.norm(z) )
# Out:
# (3+4j)
# 5.0

# %%
# by transpose?
print( np.transpose(z))
print( np.transpose(z)*z )

# by Hermitian transpose
print(z.conjugate())
print( np.transpose(z.conjugate())*z )
# Out:
# (3+4j)
# (-7+24j)
# (3-4j)
# (25+0j)

# %%
# complex vector
v = np.array( [ 3, 4j, 5+2j, np.complex(2,-5) ] )
print(v)
print( v.T )
print( np.transpose(v) )
print( np.transpose(v.conjugate()) )
print( np.transpose(v.conjugate())*v )
# Out:
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.+0.j 0.+4.j 5.+2.j 2.-5.j]
# [3.-0.j 0.-4.j 5.-2.j 2.+5.j]
# [ 9.+0.j 16.+0.j 29.+0.j 29.+0.j]

# %% [markdown]
# ---
# # VIDEO: Unit vector
# ---

# %%
# vector
v1 = np.array([ -3, 6 ])

# mu
mu = 1/np.linalg.norm(v1)

v1n = v1*mu

# plot them
plt.plot([0, v1[0]],[0, v1[1]],'b',label='v1')
h=plt.plot([0, v1n[0]],[0, v1n[1]],'r',label='v1-norm')
# Set a property on an artist object.
plt.setp(h,linewidth=5)

# axis square
plt.axis('square')
plt.axis(( -6, 6, -6, 6 ))
plt.grid()
plt.legend()
plt.show()

# %%
#Challenge
# Create two random integer vectors(R4)
# compute the lengths of the individual vectors and magnitude of their dot product
# noramalize the vectors - create a unit vector
# compute the magnitude of that dot product
np.random.seed(0)
vec1 = np.random.randint(0,10, 4)
vec2 = np.random.randint(0,10, 4)

vec1_n = np.linalg.norm(vec1)
vec2_n = np.linalg.norm(vec2)
dp = np.dot(vec1, vec2)
print(vec1_n)
print(vec2_n)
print(dp)

vec1_u = vec1 / vec1_n
vec2_u = vec2 / vec2_n
print(vec1_u)
print(vec2_u)

dp_u = np.dot(vec1_u, vec2_u)
print(dp_u)
print(dp / (vec1_n * vec2_n))
# Out:
# 6.557438524302
# 12.806248474865697
# 59
# [0.76249285 0.         0.45749571 0.45749571]
# [0.54660817 0.70278193 0.23426064 0.3904344 ]
# 0.7025801246385729
# 0.7025801246385729

# %% [markdown]
# ---
# # VIDEO: Span
# ---

# %%
# set S
S1 = np.array([1, 1, 0])
S2 = np.array([1, 7, 0])

# vectors v and w
v = np.array([1, 2, 0])
w = np.array([3, 2, 1])

# draw vectors
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot([0, S1[0]],[0, S1[1]],[0, S1[2]],'r')
ax.plot([0, S2[0]],[0, S2[1]],[0, S2[2]],'r')

ax.plot([0, v[0]],[0, v[1]],[0, v[2]],'k')
ax.plot([0, w[0]],[0, w[1]],[0, w[2]],'b')

# now draw plane
# The purpose of meshgrid is to create a rectangular grid out of an array of x values and an array of y values. Instead 
# of plotting the dot for your self. 
xx, yy = np.meshgrid(range(30), range(30))
cp = np.cross(S1,S2)
z1 = (-cp[0]*xx - cp[1]*yy)*1 / cp[2] 
ax.plot_surface(xx,yy,z1)

ax.view_init(azim=10,elev=45)
plt.show()
